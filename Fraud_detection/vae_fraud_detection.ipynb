# %% [markdown]
# # VAE for Fraud Detection

# %% [markdown]
# * Dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud#creditcard.csv

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## Data Processing
# * Convert time to real value
# * std.scaler on `Time` and `Amount`

# %%
df = pd.read_csv(".\data\creditcard.csv")
df.loc[:,"Time"] = df["Time"].apply(lambda x : x / 3600 % 24)
df.loc[:,'Amount'] = np.log(df['Amount']+1)

df_scaled = df
df_scaled['Time'] = StandardScaler().fit_transform(df_scaled['Time'].values.reshape(-1, 1))
df_scaled['Amount'] = StandardScaler().fit_transform(df_scaled['Amount'].values.reshape(-1, 1))

df_scaled_normal = df_scaled[df_scaled.Class == 0]
df_scaled_fraud = df_scaled[df_scaled.Class == 1]

# %%
print('percent of fraud transaction data %.2f%%' %(df_scaled_fraud.shape[0]/df.shape[0]*100))
# Out:
# percent of fraud transaction data 0.17%

# %%
df_scaled.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -2.486373 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -2.486373  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -2.486326 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -2.486326 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -2.486278 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  1.124303      0
# 1  0.167170  0.125895 -0.008983  0.014724 -1.114639      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  1.682368      0
# 3  0.647376 -0.221929  0.062723  0.061458  1.009339      0
# 4 -0.206010  0.502292  0.219422  0.215153  0.670241      0
#
# [5 rows x 31 columns]

# %%
train_normal, test_normal = train_test_split(df_scaled_normal, test_size=0.2)
train_normal = train_normal.drop(['Class'], axis=1) #drop the class column
test_normal = test_normal.drop(['Class'], axis=1) #drop the class column
test_fraud = df_scaled_fraud.drop(['Class'], axis=1)

train_normal = train_normal.values #transform to ndarray
test_normal = test_normal.values
test_fraud = test_fraud.values

# %% [markdown]
# ## VAE Model
# * Assume input data follows normal distribution and each features are independent.
# * Output of decoder is a vector of reconstructed mean  and a vector of reconstructed log. variance

# %%
# VAE model
class VAE(nn.Module):
    def __init__(self, input_size, h_dim, z_dim):
        super().__init__()                    # intialize nn.Module, this works
        self.fc_e1 = nn.Linear(input_size, h_dim)
        self.fc_e2a = nn.Linear(h_dim, z_dim) # latent mean vector
        self.fc_e2b = nn.Linear(h_dim, z_dim) # latent log variance vector
        
        self.fc_d1 = nn.Linear(z_dim, h_dim)         # for first layer of decoder
        self.fc_d2a = nn.Linear(h_dim, input_size)   # second layer of decoder, reconstructed mean vector
        self.fc_d2b = nn.Linear(h_dim, input_size)   # second layer of decoder, reconstructed log.var vector
        
    # Encoding
    def encode(self, x):
        h = F.relu(self.fc_e1(x))             # could be tanh
        return self.fc_e2a(h), self.fc_e2b(h) # one for mean and one for log_variance
    
    # Reparameterizing trick, Generate Random Latent Vector
    def reparameterize(self, mu, log_var):
        std_dev = torch.exp(log_var/2)  # convert log_variance to std_dev
        eps = torch.randn_like(std_dev) # sampling from N(0,1)
        return mu + eps * std_dev
        
    # Decoding
    def decode(self, z):
        """
        suppose data follows a multi-variate normal distribution,
        decoder reconstruct the mean and log.variance
        """
        h = F.relu(self.fc_d1(z))
        mu_reconst = self.fc_d2a(h)
        log_var_reconst = self.fc_d2b(h)
        # could reconstruct a sample from N(mu,var) by utilize reparameterize method
        # here we don't use it
#         x_reconst = self.reparameterize(mu_reconst, log_var_reconst)
        return mu_reconst, log_var_reconst
    
    # foward propagation
    def forward(self, x):
        mu_latent, log_var_latent = self.encode(x)   #notice the output of encoder is mean and log_variance
        z = self.reparameterize(mu_latent, log_var_latent)
        mu_reconst, log_var_reconst = self.decode(z)
        return mu_latent, log_var_latent, mu_reconst, log_var_reconst

# %% [markdown]
# ## Training
# * Define reconstruction loss as negative loglikelihood
#   $$L(\tilde{\mathbf{x}}) = \ln (|\mathbf{\Sigma}_{\theta^*}|)+(\tilde{\mathbf{x}}-\boldsymbol{\mu}_{\theta^*})^{\top} \mathbf{\Sigma}_{\theta^*}^{-1}(\tilde{\mathbf{x}}-\boldsymbol{\mu}_{\theta^*})$$
# * Ref. for reconstruction loss
# * https://discuss.pytorch.org/t/multivariate-gaussian-variational-autoencoder-the-decoder-part/58235

# %%
def calculate_reconst_loss(x, mu_reconst, log_var_reconst):
    # neg log likelihood of x under normal
    reconst_loss = 0.5 * torch.sum(30 * np.log(2 * np.pi) + log_var_reconst + (x - mu_reconst)**2 / torch.exp(log_var_reconst))
    return reconst_loss

# %%
# ======== TRAINING DATA =============
train_tensor = torch.from_numpy(train_normal)
print("Size of Training Data:", train_normal.shape)


# ======== Hyper-parameters ========
input_size = train_normal.shape[1]  # here it's 30
h_dim = 10   # dimension of first layer
z_dim = 5    # will be 8, second layer, dim of latent vector z

num_epochs = 50
learning_rate = 1e-3

batch_size = 256
data_loader = torch.utils.data.DataLoader(dataset=train_tensor.float(),
                                          batch_size=batch_size, 
                                          shuffle=True)

# Create Instance for VAE
model = VAE(input_size = input_size, h_dim=h_dim, z_dim=z_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

ELBO_all, loglikelihood_all, KL_div_all  = [], [], []



for epoch in range(num_epochs):
    for i, x in enumerate(data_loader):
        
        # forward propagation
        mu_latent, log_var_latent, mu_reconst, log_var_reconst = model(x)
        
        # ================= COMPUTING LOSS & BACK-PROP ======================
        
        # using neg. log likelihood of x under normal
        reconst_loss = calculate_reconst_loss(x, mu_reconst, log_var_reconst) / batch_size
        # compute KL divergence
        kl_div = - 0.5 * torch.sum(1 + log_var_latent - mu_latent.pow(2) - log_var_latent.exp()) / batch_size
        
        # Back propagation, want to minimize loss
        # Notice -- 
        # ELBO = loglikelihood - KL_div, we want to maximize ELBO
        # maximize ELBO <==> minimize (ReconstructionLoss + KL_div)
        loss = (reconst_loss + kl_div)   # type(loss) = torch.Tensor
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # ================== SHOW TRAINING PROGRESS ==========================
        ELBO_all.append(-loss.item() if -loss.item() < -810 else -810)
        loglikelihood_all.append(-reconst_loss.item() if -reconst_loss.item() < -810 else -810)
        KL_div_all.append(kl_div.item())
        if (i%100)==0:
            print("Epoch[{}/{}], Step [{}/{}], Reconst Loss: {:.2f}, KL Div: {:.2f}, ELBO: {:.2f}" 
                   .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item(), kl_div.item(), -loss.item()))
# Out:
# Size of Training Data: (227452, 30)
# Epoch[1/50], Step [1/889], Reconst Loss: 843.62, KL Div: 0.26, ELBO: -843.88
# Epoch[1/50], Step [101/889], Reconst Loss: 841.19, KL Div: 0.16, ELBO: -841.35
# Epoch[1/50], Step [201/889], Reconst Loss: 840.06, KL Div: 0.15, ELBO: -840.21
# Epoch[1/50], Step [301/889], Reconst Loss: 841.50, KL Div: 0.22, ELBO: -841.72
# Epoch[1/50], Step [401/889], Reconst Loss: 842.18, KL Div: 0.38, ELBO: -842.56
# Epoch[1/50], Step [501/889], Reconst Loss: 837.05, KL Div: 0.33, ELBO: -837.38
# Epoch[1/50], Step [601/889], Reconst Loss: 836.25, KL Div: 0.83, ELBO: -837.07
# Epoch[1/50], Step [701/889], Reconst Loss: 832.93, KL Div: 1.22, ELBO: -834.15
# Epoch[1/50], Step [801/889], Reconst Loss: 832.01, KL Div: 1.33, ELBO: -833.35
# Epoch[2/50], Step [1/889], Reconst Loss: 832.85, KL Div: 2.02, ELBO: -834.87
# Epoch[2/50], Step [101/889], Reconst Loss: 831.99, KL Div: 1.70, ELBO: -833.69
# Epoch[2/50], Step [201/889], Reconst Loss: 829.48, KL Div: 2.01, ELBO: -831.49
# Epoch[2/50], Step [301/889], Reconst Loss: 830.34, KL Div: 2.19, ELBO: -832.53
# Epoch[2/50], Step [401/889], Reconst Loss: 828.93, KL Div: 2.35, ELBO: -831.28
# Epoch[2/50], Step [501/889], Reconst Loss: 829.00, KL Div: 2.63, ELBO: -831.63
# Epoch[2/50], Step [601/889], Reconst Loss: 827.46, KL Div: 2.54, ELBO: -830.00
# Epoch[2/50], Step [701/889], Reconst Loss: 829.10, KL Div: 2.60, ELBO: -831.70
# Epoch[2/50], Step [801/889], Reconst Loss: 827.42, KL Div: 2.67, ELBO: -830.08
# Epoch[3/50], Step [1/889], Reconst Loss: 828.23, KL Div: 3.04, ELBO: -831.27
# Epoch[3/50], Step [101/889], Reconst Loss: 827.86, KL Div: 2.99, ELBO: -830.85
# Epoch[3/50], Step [201/889], Reconst Loss: 825.91, KL Div: 3.06, ELBO: -828.98
# Epoch[3/50], Step [301/889], Reconst Loss: 824.93, KL Div: 3.40, ELBO: -828.33
# Epoch[3/50], Step [401/889], Reconst Loss: 824.84, KL Div: 3.80, ELBO: -828.65
# Epoch[3/50], Step [501/889], Reconst Loss: 826.07, KL Div: 4.24, ELBO: -830.31
# Epoch[3/50], Step [601/889], Reconst Loss: 825.70, KL Div: 4.00, ELBO: -829.70
# Epoch[3/50], Step [701/889], Reconst Loss: 824.94, KL Div: 4.06, ELBO: -829.00
# Epoch[3/50], Step [801/889], Reconst Loss: 825.66, KL Div: 4.05, ELBO: -829.70
# Epoch[4/50], Step [1/889], Reconst Loss: 825.23, KL Div: 4.00, ELBO: -829.24
# Epoch[4/50], Step [101/889], Reconst Loss: 822.92, KL Div: 4.23, ELBO: -827.15
# Epoch[4/50], Step [201/889], Reconst Loss: 824.73, KL Div: 4.53, ELBO: -829.26
# Epoch[4/50], Step [301/889], Reconst Loss: 825.82, KL Div: 4.37, ELBO: -830.20
# Epoch[4/50], Step [401/889], Reconst Loss: 824.14, KL Div: 4.26, ELBO: -828.40
# Epoch[4/50], Step [501/889], Reconst Loss: 823.38, KL Div: 4.44, ELBO: -827.83
# Epoch[4/50], Step [601/889], Reconst Loss: 824.02, KL Div: 4.55, ELBO: -828.57
# Epoch[4/50], Step [701/889], Reconst Loss: 824.13, KL Div: 4.51, ELBO: -828.65
# Epoch[4/50], Step [801/889], Reconst Loss: 824.53, KL Div: 4.54, ELBO: -829.07
# Epoch[5/50], Step [1/889], Reconst Loss: 823.86, KL Div: 4.47, ELBO: -828.33
# Epoch[5/50], Step [101/889], Reconst Loss: 825.16, KL Div: 4.53, ELBO: -829.69
# Epoch[5/50], Step [201/889], Reconst Loss: 823.99, KL Div: 4.41, ELBO: -828.41
# Epoch[5/50], Step [301/889], Reconst Loss: 824.74, KL Div: 4.83, ELBO: -829.57
# Epoch[5/50], Step [401/889], Reconst Loss: 824.08, KL Div: 4.60, ELBO: -828.68
# Epoch[5/50], Step [501/889], Reconst Loss: 823.78, KL Div: 4.58, ELBO: -828.36
# Epoch[5/50], Step [601/889], Reconst Loss: 822.90, KL Div: 5.03, ELBO: -827.92
# Epoch[5/50], Step [701/889], Reconst Loss: 821.48, KL Div: 4.82, ELBO: -826.30
# Epoch[5/50], Step [801/889], Reconst Loss: 822.88, KL Div: 5.13, ELBO: -828.01
# Epoch[6/50], Step [1/889], Reconst Loss: 822.71, KL Div: 5.14, ELBO: -827.85
# Epoch[6/50], Step [101/889], Reconst Loss: 822.14, KL Div: 5.32, ELBO: -827.46
# Epoch[6/50], Step [201/889], Reconst Loss: 823.41, KL Div: 5.42, ELBO: -828.82
# Epoch[6/50], Step [301/889], Reconst Loss: 821.95, KL Div: 5.49, ELBO: -827.44
# Epoch[6/50], Step [401/889], Reconst Loss: 822.36, KL Div: 5.79, ELBO: -828.15
# Epoch[6/50], Step [501/889], Reconst Loss: 823.36, KL Div: 5.60, ELBO: -828.96
# Epoch[6/50], Step [601/889], Reconst Loss: 821.12, KL Div: 5.75, ELBO: -826.88
# Epoch[6/50], Step [701/889], Reconst Loss: 820.94, KL Div: 5.78, ELBO: -826.72
# Epoch[6/50], Step [801/889], Reconst Loss: 820.79, KL Div: 6.07, ELBO: -826.86
# Epoch[7/50], Step [1/889], Reconst Loss: 822.53, KL Div: 5.77, ELBO: -828.30
# Epoch[7/50], Step [101/889], Reconst Loss: 822.38, KL Div: 6.17, ELBO: -828.55
# Epoch[7/50], Step [201/889], Reconst Loss: 822.59, KL Div: 5.85, ELBO: -828.44
# Epoch[7/50], Step [301/889], Reconst Loss: 822.25, KL Div: 5.89, ELBO: -828.14
# Epoch[7/50], Step [401/889], Reconst Loss: 820.93, KL Div: 6.11, ELBO: -827.04
# Epoch[7/50], Step [501/889], Reconst Loss: 820.75, KL Div: 6.42, ELBO: -827.17
# Epoch[7/50], Step [601/889], Reconst Loss: 821.97, KL Div: 6.23, ELBO: -828.20
# Epoch[7/50], Step [701/889], Reconst Loss: 823.01, KL Div: 5.92, ELBO: -828.92
# Epoch[21/50], Step [501/889], Reconst Loss: 816.98, KL Div: 7.64, ELBO: -824.62
# Epoch[21/50], Step [601/889], Reconst Loss: 818.82, KL Div: 7.75, ELBO: -826.57
# Epoch[21/50], Step [701/889], Reconst Loss: 818.22, KL Div: 7.41, ELBO: -825.63
# Epoch[21/50], Step [801/889], Reconst Loss: 819.76, KL Div: 7.42, ELBO: -827.17
# Epoch[22/50], Step [1/889], Reconst Loss: 818.08, KL Div: 7.41, ELBO: -825.48
# Epoch[22/50], Step [101/889], Reconst Loss: 819.13, KL Div: 7.39, ELBO: -826.52
# Epoch[22/50], Step [201/889], Reconst Loss: 819.47, KL Div: 7.05, ELBO: -826.52
# Epoch[22/50], Step [301/889], Reconst Loss: 819.54, KL Div: 7.29, ELBO: -826.84
# Epoch[22/50], Step [401/889], Reconst Loss: 818.81, KL Div: 7.18, ELBO: -825.98
# Epoch[22/50], Step [501/889], Reconst Loss: 818.37, KL Div: 7.26, ELBO: -825.63
# Epoch[22/50], Step [601/889], Reconst Loss: 817.58, KL Div: 7.74, ELBO: -825.32
# Epoch[22/50], Step [701/889], Reconst Loss: 818.35, KL Div: 7.37, ELBO: -825.71
# Epoch[22/50], Step [801/889], Reconst Loss: 818.81, KL Div: 7.64, ELBO: -826.46
# Epoch[23/50], Step [1/889], Reconst Loss: 819.52, KL Div: 7.18, ELBO: -826.70
# Epoch[23/50], Step [101/889], Reconst Loss: 817.39, KL Div: 7.55, ELBO: -824.94
# Epoch[23/50], Step [201/889], Reconst Loss: 819.29, KL Div: 7.41, ELBO: -826.70
# Epoch[23/50], Step [301/889], Reconst Loss: 818.45, KL Div: 7.52, ELBO: -825.97
# Epoch[23/50], Step [401/889], Reconst Loss: 818.96, KL Div: 7.58, ELBO: -826.55
# Epoch[23/50], Step [501/889], Reconst Loss: 818.57, KL Div: 7.40, ELBO: -825.97
# Epoch[23/50], Step [601/889], Reconst Loss: 818.72, KL Div: 7.29, ELBO: -826.01
# Epoch[23/50], Step [701/889], Reconst Loss: 819.00, KL Div: 7.38, ELBO: -826.38
# Epoch[23/50], Step [801/889], Reconst Loss: 817.98, KL Div: 7.66, ELBO: -825.63
# Epoch[24/50], Step [1/889], Reconst Loss: 818.39, KL Div: 7.68, ELBO: -826.07
# Epoch[24/50], Step [101/889], Reconst Loss: 819.93, KL Div: 7.11, ELBO: -827.04
# Epoch[24/50], Step [201/889], Reconst Loss: 818.19, KL Div: 7.49, ELBO: -825.69
# Epoch[24/50], Step [301/889], Reconst Loss: 820.65, KL Div: 7.16, ELBO: -827.81
# Epoch[24/50], Step [401/889], Reconst Loss: 819.55, KL Div: 7.55, ELBO: -827.09
# Epoch[24/50], Step [501/889], Reconst Loss: 818.47, KL Div: 7.43, ELBO: -825.90
# Epoch[24/50], Step [601/889], Reconst Loss: 821.18, KL Div: 7.21, ELBO: -828.39
# Epoch[24/50], Step [701/889], Reconst Loss: 817.56, KL Div: 7.27, ELBO: -824.83
# Epoch[24/50], Step [801/889], Reconst Loss: 818.22, KL Div: 7.32, ELBO: -825.54
# Epoch[31/50], Step [701/889], Reconst Loss: 817.12, KL Div: 7.67, ELBO: -824.79
# Epoch[31/50], Step [801/889], Reconst Loss: 818.90, KL Div: 7.44, ELBO: -826.34
# Epoch[32/50], Step [1/889], Reconst Loss: 819.69, KL Div: 7.62, ELBO: -827.31
# Epoch[32/50], Step [101/889], Reconst Loss: 820.02, KL Div: 6.89, ELBO: -826.91
# Epoch[32/50], Step [201/889], Reconst Loss: 816.77, KL Div: 8.01, ELBO: -824.78
# Epoch[32/50], Step [301/889], Reconst Loss: 818.33, KL Div: 7.54, ELBO: -825.87
# Epoch[32/50], Step [401/889], Reconst Loss: 821.06, KL Div: 7.33, ELBO: -828.38
# Epoch[32/50], Step [501/889], Reconst Loss: 818.81, KL Div: 7.28, ELBO: -826.09
# Epoch[32/50], Step [601/889], Reconst Loss: 818.50, KL Div: 7.36, ELBO: -825.86
# Epoch[32/50], Step [701/889], Reconst Loss: 818.53, KL Div: 7.49, ELBO: -826.02
# Epoch[32/50], Step [801/889], Reconst Loss: 818.74, KL Div: 7.41, ELBO: -826.16
# Epoch[33/50], Step [1/889], Reconst Loss: 817.38, KL Div: 7.67, ELBO: -825.05
# Epoch[33/50], Step [101/889], Reconst Loss: 819.57, KL Div: 7.18, ELBO: -826.75
# Epoch[33/50], Step [201/889], Reconst Loss: 817.86, KL Div: 7.66, ELBO: -825.52
# Epoch[33/50], Step [301/889], Reconst Loss: 818.75, KL Div: 7.52, ELBO: -826.28
# Epoch[33/50], Step [401/889], Reconst Loss: 817.96, KL Div: 7.64, ELBO: -825.60
# Epoch[33/50], Step [501/889], Reconst Loss: 817.51, KL Div: 7.33, ELBO: -824.85
# Epoch[33/50], Step [601/889], Reconst Loss: 819.26, KL Div: 7.39, ELBO: -826.65
# Epoch[33/50], Step [701/889], Reconst Loss: 818.39, KL Div: 7.80, ELBO: -826.19
# Epoch[33/50], Step [801/889], Reconst Loss: 817.84, KL Div: 7.62, ELBO: -825.46
# Epoch[34/50], Step [1/889], Reconst Loss: 821.17, KL Div: 7.50, ELBO: -828.67
# Epoch[34/50], Step [101/889], Reconst Loss: 818.20, KL Div: 7.57, ELBO: -825.77
# Epoch[34/50], Step [201/889], Reconst Loss: 818.21, KL Div: 7.51, ELBO: -825.72
# Epoch[34/50], Step [301/889], Reconst Loss: 817.08, KL Div: 7.86, ELBO: -824.94
# Epoch[34/50], Step [401/889], Reconst Loss: 817.21, KL Div: 7.86, ELBO: -825.07
# Epoch[34/50], Step [501/889], Reconst Loss: 815.78, KL Div: 7.91, ELBO: -823.69
# Epoch[34/50], Step [601/889], Reconst Loss: 818.03, KL Div: 7.53, ELBO: -825.56
# Epoch[34/50], Step [701/889], Reconst Loss: 817.05, KL Div: 7.68, ELBO: -824.73
# Epoch[34/50], Step [801/889], Reconst Loss: 819.44, KL Div: 7.37, ELBO: -826.81
# Epoch[35/50], Step [1/889], Reconst Loss: 817.17, KL Div: 7.62, ELBO: -824.79
# Epoch[35/50], Step [101/889], Reconst Loss: 817.46, KL Div: 7.64, ELBO: -825.10
# Epoch[45/50], Step [401/889], Reconst Loss: 817.37, KL Div: 7.82, ELBO: -825.19
# Epoch[45/50], Step [501/889], Reconst Loss: 818.53, KL Div: 7.72, ELBO: -826.25
# Epoch[45/50], Step [601/889], Reconst Loss: 816.75, KL Div: 7.83, ELBO: -824.58
# Epoch[45/50], Step [701/889], Reconst Loss: 816.91, KL Div: 7.64, ELBO: -824.55
# Epoch[45/50], Step [801/889], Reconst Loss: 818.79, KL Div: 7.98, ELBO: -826.77
# Epoch[46/50], Step [1/889], Reconst Loss: 818.03, KL Div: 7.68, ELBO: -825.71
# Epoch[46/50], Step [101/889], Reconst Loss: 818.78, KL Div: 7.70, ELBO: -826.48
# Epoch[46/50], Step [201/889], Reconst Loss: 819.07, KL Div: 7.85, ELBO: -826.93
# Epoch[46/50], Step [301/889], Reconst Loss: 815.70, KL Div: 7.79, ELBO: -823.49
# Epoch[46/50], Step [401/889], Reconst Loss: 817.00, KL Div: 7.90, ELBO: -824.90
# Epoch[46/50], Step [501/889], Reconst Loss: 818.66, KL Div: 7.57, ELBO: -826.23
# Epoch[46/50], Step [601/889], Reconst Loss: 818.56, KL Div: 7.68, ELBO: -826.24
# Epoch[46/50], Step [701/889], Reconst Loss: 817.55, KL Div: 7.36, ELBO: -824.91
# Epoch[46/50], Step [801/889], Reconst Loss: 819.84, KL Div: 7.09, ELBO: -826.92
# Epoch[47/50], Step [1/889], Reconst Loss: 818.43, KL Div: 7.59, ELBO: -826.01
# Epoch[47/50], Step [101/889], Reconst Loss: 819.15, KL Div: 7.21, ELBO: -826.36
# Epoch[47/50], Step [201/889], Reconst Loss: 816.97, KL Div: 7.44, ELBO: -824.41
# Epoch[47/50], Step [301/889], Reconst Loss: 816.31, KL Div: 7.57, ELBO: -823.88
# Epoch[47/50], Step [401/889], Reconst Loss: 815.93, KL Div: 8.17, ELBO: -824.10
# Epoch[47/50], Step [501/889], Reconst Loss: 816.86, KL Div: 7.79, ELBO: -824.65
# Epoch[47/50], Step [601/889], Reconst Loss: 818.47, KL Div: 7.38, ELBO: -825.85
# Epoch[47/50], Step [701/889], Reconst Loss: 818.93, KL Div: 7.36, ELBO: -826.29
# Epoch[47/50], Step [801/889], Reconst Loss: 818.67, KL Div: 7.64, ELBO: -826.31
# Epoch[48/50], Step [1/889], Reconst Loss: 818.66, KL Div: 7.74, ELBO: -826.40
# Epoch[48/50], Step [101/889], Reconst Loss: 816.32, KL Div: 7.74, ELBO: -824.06
# Epoch[48/50], Step [201/889], Reconst Loss: 818.32, KL Div: 7.73, ELBO: -826.05
# Epoch[48/50], Step [301/889], Reconst Loss: 818.61, KL Div: 7.47, ELBO: -826.09
# Epoch[48/50], Step [401/889], Reconst Loss: 818.58, KL Div: 7.49, ELBO: -826.06
# Epoch[48/50], Step [501/889], Reconst Loss: 818.25, KL Div: 7.60, ELBO: -825.85
# Epoch[48/50], Step [601/889], Reconst Loss: 818.04, KL Div: 7.59, ELBO: -825.63
# Epoch[48/50], Step [701/889], Reconst Loss: 818.48, KL Div: 7.56, ELBO: -826.04
# Epoch[48/50], Step [801/889], Reconst Loss: 819.46, KL Div: 7.43, ELBO: -826.89
# Epoch[49/50], Step [1/889], Reconst Loss: 817.72, KL Div: 7.52, ELBO: -825.24
# Epoch[49/50], Step [101/889], Reconst Loss: 816.63, KL Div: 8.02, ELBO: -824.65
# Epoch[49/50], Step [201/889], Reconst Loss: 817.27, KL Div: 7.47, ELBO: -824.74
# Epoch[49/50], Step [301/889], Reconst Loss: 818.56, KL Div: 7.49, ELBO: -826.04
# Epoch[49/50], Step [401/889], Reconst Loss: 817.52, KL Div: 7.69, ELBO: -825.21
# Epoch[49/50], Step [501/889], Reconst Loss: 815.76, KL Div: 7.90, ELBO: -823.66
# Epoch[49/50], Step [601/889], Reconst Loss: 817.75, KL Div: 7.58, ELBO: -825.33
# Epoch[49/50], Step [701/889], Reconst Loss: 818.60, KL Div: 7.52, ELBO: -826.12
# Epoch[49/50], Step [801/889], Reconst Loss: 817.38, KL Div: 7.78, ELBO: -825.16
# Epoch[50/50], Step [1/889], Reconst Loss: 818.06, KL Div: 7.51, ELBO: -825.57
# Epoch[50/50], Step [101/889], Reconst Loss: 817.45, KL Div: 7.58, ELBO: -825.03
# Epoch[50/50], Step [201/889], Reconst Loss: 817.60, KL Div: 7.85, ELBO: -825.45
# Epoch[50/50], Step [301/889], Reconst Loss: 818.89, KL Div: 7.53, ELBO: -826.42
# Epoch[50/50], Step [401/889], Reconst Loss: 818.59, KL Div: 7.39, ELBO: -825.99
# Epoch[50/50], Step [501/889], Reconst Loss: 818.61, KL Div: 7.40, ELBO: -826.01
# Epoch[50/50], Step [601/889], Reconst Loss: 817.15, KL Div: 7.68, ELBO: -824.82
# Epoch[50/50], Step [701/889], Reconst Loss: 816.77, KL Div: 7.68, ELBO: -824.45
# Epoch[50/50], Step [801/889], Reconst Loss: 817.80, KL Div: 7.75, ELBO: -825.55

# %% [markdown]
# * Plot training curves

# %%
def plot(data_y1,data_y2=None,data_x1=None,data_x2=None,x_label=None,y_label=None,title=None,
        xlimit=None,ylimit=None,figsize=(8,4)):
    fig = plt.figure(figsize=figsize)
    ax1 = fig.add_subplot(111)
    if data_x1 != None:
        ax1.plot(data_x1,data_y1)
    else:
        ax1.plot(data_y1)
    if data_y2 != None and data_x2!=None:
        ax1.plot(data_x2,data_y2)
    elif data_y2 != None:
        ax1.plot(data_y2)
    ax1.set_ylabel(y_label)
    ax1.set_xlabel(x_label)
    ax1.set_title(title)
    plt.xlim(xlimit)
    plt.ylim(ylimit)
    plt.show()

# %%
loglikelihood_all = np.array(loglikelihood_all)
plot(data_y1=loglikelihood_all[(loglikelihood_all>-870)&(loglikelihood_all<-790)][:15000],
     data_x1=None,x_label='n_iter',
     y_label='Log-likelihood',title='Log-likelihood vs num of updates',
     figsize = (4,6))

# %%
KL_div_all = np.array(KL_div_all)
plot(data_y1=KL_div_all[KL_div_all<1e5][:20000],
     data_x1=None,x_label='n_iter',
     y_label='KL_divergence',title='KL Divergence vs num of updates',
    figsize=(4,6))

# %%
ELBO_all = np.array(ELBO_all)
plot(data_y1=ELBO_all[(ELBO_all>-880)],
     data_x1=None,x_label='n_iter',
     y_label='ELBO',title='ELBO vs num of updates')

# %% [markdown]
# ## Prediction

# %%
def calculate_sample_reconst_loss(mu,log_var,sample):
    """
    mu: 1*n_features, vector
    var: 1*n_features, vector
    """
    loss = calculate_reconst_loss(sample, mu, log_var)

    return loss.item()

# %%
def getReconstLoss(data,n_sample=100):
    result = []
    for i in range(data.shape[0]):
        if (i%1000==0):
            print('[%d/%d] samples finished' %(i,data.shape[0]))
        train_scaled_tensor = torch.from_numpy(data[i])
        reconst_loss = 0
        sample = train_scaled_tensor.float()   # 
        with torch.no_grad():
            _, _, mu_reconst, log_var_reconst = model(sample)
            reconst_loss = calculate_sample_reconst_loss(mu_reconst, 
                                                         log_var_reconst,
                                                         sample) 
            result.append(reconst_loss)
    return np.array(result)
reconst_loss_normal = getReconstLoss(test_normal)
reconst_loss_fraud = getReconstLoss(test_fraud)
# Out:
# [0/56863] samples finished
# [1000/56863] samples finished
# [2000/56863] samples finished
# [3000/56863] samples finished
# [4000/56863] samples finished
# [5000/56863] samples finished
# [6000/56863] samples finished
# [7000/56863] samples finished
# [8000/56863] samples finished
# [9000/56863] samples finished
# [10000/56863] samples finished
# [11000/56863] samples finished
# [12000/56863] samples finished
# [13000/56863] samples finished
# [14000/56863] samples finished
# [15000/56863] samples finished
# [16000/56863] samples finished
# [17000/56863] samples finished
# [18000/56863] samples finished
# [19000/56863] samples finished
# [20000/56863] samples finished
# [21000/56863] samples finished
# [22000/56863] samples finished
# [23000/56863] samples finished
# [24000/56863] samples finished
# [25000/56863] samples finished
# [26000/56863] samples finished
# [27000/56863] samples finished
# [28000/56863] samples finished
# [29000/56863] samples finished
# [30000/56863] samples finished
# [31000/56863] samples finished
# [32000/56863] samples finished
# [33000/56863] samples finished
# [34000/56863] samples finished
# [35000/56863] samples finished
# [36000/56863] samples finished
# [37000/56863] samples finished
# [38000/56863] samples finished
# [39000/56863] samples finished
# [40000/56863] samples finished
# [41000/56863] samples finished
# [42000/56863] samples finished
# [43000/56863] samples finished
# [44000/56863] samples finished
# [45000/56863] samples finished
# [46000/56863] samples finished
# [47000/56863] samples finished
# [48000/56863] samples finished
# [49000/56863] samples finished
# [50000/56863] samples finished
# [51000/56863] samples finished
# [52000/56863] samples finished
# [53000/56863] samples finished
# [54000/56863] samples finished
# [55000/56863] samples finished
# [56000/56863] samples finished
# [0/492] samples finished

# %% [markdown]
# ## Evaluation

# %%
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(8,4))
plt.hist([reconst_loss_normal[7000:8000],
          reconst_loss_fraud],80,label=['non-fraud','frauud']);
plt.legend(loc='best')
plt.xlabel('Reconstructioon Loss')
plt.ylabel('Count')
plt.title('Distribution of Reconstruction Loss')
# Out:
# Text(0.5, 1.0, 'Distribution of Reconstruction Loss')

# %%
label_fraud = np.ones(shape=reconst_loss_fraud.shape)
label_normal = np.zeros(shape=reconst_loss_normal.shape)
label_all = np.concatenate((label_fraud , label_normal))
reconst_loss_all = np.concatenate((reconst_loss_fraud, reconst_loss_normal))

# %%
fpr_vae, tpr_vae, threshold = roc_curve(label_all, reconst_loss_all)
auc_vae = roc_auc_score(label_all, reconst_loss_all)

plt.figure(figsize=(6,4))
plt.plot(fpr_vae,tpr_vae,label="VAE ROC Curve, auc= %.3f"%(auc_vae))
plt.title('VAE Roc Curve')
# plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.legend(loc='best')
plt.show()

# %%
idx_optimal = np.argmax(tpr_vae-fpr_vae) # optimal point on ROC curve
threshold_optimal = threshold[idx_optimal]
tpr_optimal, fpr_optimal = tpr_vae[idx_optimal], fpr_vae[idx_optimal]
print("Optimal Threshold of Neg. Log Likelihood is %.3f, with TPR= %.3f, FPR= %.3f" 
      %(threshold_optimal,tpr_optimal,fpr_optimal))
# Out:
# Optimal Threshold of Neg. Log Likelihood is 851.246, with TPR= 0.880, FPR= 0.030

# %%
def calculate_fnr(y_true,y_pred):
    confMat = confusion_matrix(y_true,y_pred)
    FN = confMat[1,0]
    TP = confMat[1,1]
    FNR = FN/(TP+FN)
    return FNR

# %%
def vae_prediction(nll,thres):
    result = []
    for item in nll:
        if item>=thres:
            result.append(1)
        else:
            result.append(0)
    return np.array(result)
y_pred_vae = vae_prediction(reconst_loss_all, threshold_optimal)
FNR = calculate_fnr(label_all,y_pred_vae)
print("FNR of VAE is %.2f%%" %(FNR*100))
# Out:
# FNR of VAE is 11.99%

# %% [markdown]
# ## Comparison with Random Forest and Logistic Reg.

# %% [markdown]
# ### Prepare data for supervised model

# %%
df_scaled_normal = df_scaled[df_scaled.Class == 0]
df_scaled_fraud = df_scaled[df_scaled.Class == 1]
train_normal_tree, test_normal_tree = train_test_split(df_scaled_normal, test_size=0.8) # reduce imbalance
train_fraud_tree,test_fraud_tree = train_test_split(df_scaled_fraud, test_size=0.2)
train_normal_tree = train_normal_tree.drop(['Class'], axis=1)  # drop the class column
train_fraud_tree = train_fraud_tree.drop(['Class'], axis=1)  # drop the class column
test_normal_tree = test_normal_tree.drop(['Class'], axis=1)    # drop the class column
test_fraud_tree = test_fraud_tree.drop(['Class'],axis=1)

X_train = np.concatenate((train_normal_tree,train_fraud_tree))
y_normal = np.zeros(shape=train_normal_tree.shape[0])
y_fraud = np.ones(shape=train_fraud_tree.shape[0])
y_train = np.concatenate((y_normal,y_fraud))


X_test = np.concatenate((test_normal_tree,test_fraud_tree))
y_normal = np.zeros(shape=test_normal_tree.shape[0])
y_fraud = np.ones(shape=test_fraud_tree.shape[0])
y_test = np.concatenate((y_normal,y_fraud))

# %% [markdown]
# ### Random Forest

# %%
clf = RandomForestClassifier(n_estimators=100,max_depth=1,n_jobs=-1)
clf.fit(X_train[-2000:],y_train[-2000:])
y_prob_rf = clf.predict_proba(X_test)[:,1]
y_pred_rf = (np.sign(y_prob_rf-0.5)+1)/2
y_pred_rf = y_pred_rf.astype(int)
print(confusion_matrix(y_test,y_pred_rf))
# Out:
# [[227392     60]
#  [    19     80]]

# %%
fpr_rf, tpr_rf, threshold_roc = roc_curve(y_test, y_prob_rf)

idx_optimal = np.argmax(tpr_rf-fpr_rf) # optimal point on ROC curve
threshold_roc_optimal = threshold_roc[idx_optimal]
tpr_optimal, fpr_optimal = tpr_rf[idx_optimal], fpr_rf[idx_optimal]
print("Optimal threshold_roc of Prob. is %.2f"%(threshold_roc_optimal))

fnr_rf =  calculate_fnr(y_test,y_pred_rf)
print('True Pos. Rate for Random Forest: %.2f%%' % (tpr_optimal*100))
print('False Neg. Rate for Random Forest: %.2f%%' % (fnr_rf*100))
print('False Pos. Rate for Random Forest: %.2f%%' % (fpr_optimal*100))
# Out:
# Optimal threshold_roc of Prob. is 0.23
# True Pos. Rate for Random Forest: 86.87%
# False Neg. Rate for Random Forest: 19.19%
# False Pos. Rate for Random Forest: 0.68%

# %%
auc_rf = roc_auc_score(y_test, y_prob_rf)
plt.plot(fpr_rf,tpr_rf,label="Roc curve - RF, auc="+str(auc_rf))
plt.title('Random Forest Roc Curve')
plt.ylabel('True Positive Rate')
plt.xlabel("False Positive Rate")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0,C=1)
clf.fit(X_train[:],y_train[:])
y_prob_lr = clf.predict_proba(X_test)[:,1]
y_pred_lr = (np.sign(y_prob_lr-0.5)+1)/2
y_pred_lr = y_pred_lr.astype(int)
print(confusion_matrix(y_test,y_pred_lr))
# Out:
# [[227385     67]
#  [    22     77]]

# %%
fpr_lr, tpr_lr, threshold = roc_curve(y_test, y_prob_lr)

idx_optimal = np.argmax(tpr_lr-fpr_lr) # optimal point on ROC curve
threshold_optimal = threshold[idx_optimal]
tpr_lr_optimal, fpr_lr_optimal = tpr_lr[idx_optimal], fpr_lr[idx_optimal]
print("Optimal Threshold of Prob. is %.2f"%(threshold_optimal))

fnr_lr =  calculate_fnr(y_test,y_pred_lr)
print('True Pos. Rate for Logistic Regression: %.2f%%' % (tpr_lr_optimal*100))
print('False Neg. Rate for Logistic Regression: %.2f%%' % (fnr_lr*100))
print('False Pos. Rate for Logistic Regression: %.2f%%' % (fpr_lr_optimal*100))

auc_lr = roc_auc_score(y_test, y_prob_lr)
plt.plot(fpr_lr,tpr_lr,label="ROC Curve, LR, auc="+str(auc_lr))
plt.title('Logistic Regression Roc Curve')
plt.ylabel('True Positive Rate')
plt.xlabel("False Positive Rate")
plt.legend(loc='best')
plt.show()
# Out:
# Optimal Threshold of Prob. is 0.00
# True Pos. Rate for Logistic Regression: 95.96%
# False Neg. Rate for Logistic Regression: 22.22%
# False Pos. Rate for Logistic Regression: 5.69%

# %% [markdown]
# ### Plot ROC curves of three models

# %%
plt.figure(figsize=(8,4))
plt.plot(fpr_vae,tpr_vae,label="VAE, auc=%.3f"%(auc_vae))
plt.plot(fpr_rf,tpr_rf,label="Random Forest, auc=%.4f"%(auc_rf)) # plotting t, a separately 
plt.plot(fpr_lr,tpr_lr,label="Logistic Regresson, auc=%.4f"%(auc_lr)) # plotting t, b separately 
plt.ylabel('True Positive Rate')
plt.xlabel("False Positive Rate")
plt.legend(loc='best')
plt.title('ROC Curve of Different Models')
plt.show()
