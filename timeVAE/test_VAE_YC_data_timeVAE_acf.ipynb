# %%
from collections.abc import Mapping
print(Mapping)
# Out:
# <class 'collections.abc.Mapping'>

# %%
import os, warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
warnings.filterwarnings('ignore') 

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # disabling gpu usage because my cuda is corrupted, needs to be fixed. 

import sys
import numpy as np , pandas as pd
import time
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from vae_dense_model import VariationalAutoencoderDense as VAE_Dense
from vae_conv_model import VariationalAutoencoderConv as VAE_Conv
from vae_conv_I_model_acf import VariationalAutoencoderConvInterpretable as TimeVAE
import utils

# %%
from pre_post_processing import *

# %%
import time
start = time.time()

data_dir = './datasets/'
# ----------------------------------------------------------------------------------
# choose model
vae_type = 'timeVAE'           # vae_dense, vae_conv, timeVAE
# ----------------------------------------------------------------------------------
# read data    
dataset = 'yield-curve-rates-1990-2021'            # sine, stocks, energy
perc_of_train_used = 20     # 5, 10, 20, 100    
valid_perc = 0.1
input_file = f'{dataset}.csv'
df = pd.read_csv(data_dir + input_file).set_index('Date')
#df_ret=(np.log(df/df.shift(1))).values[1:]   #Log return

# %%
df.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
tenor_list = ['1 Mo', '3 Mo', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '10 Yr', '30 Yr']

# %%
# df2 = df.values
df_ret = (df[tenor_list] - df[tenor_list].shift(periods=1)).dropna()
# df_ret = df.diff().dropna()

# %%
df_ret.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
scaler_type="StandardScaler"
seq_length=24
returns_raw=df_ret.values
_, returns_scaled, scaler = data_to_scaled_data(returns_raw, scaler_type=scaler_type)
print(returns_scaled.shape)
returns_scaled_rolled = split_series(returns_scaled, n_past=seq_length, n_future=0)
print (returns_scaled_rolled.shape)
# Out:
# (4105, 9)
# (4082, 24, 9)

# %%
import random
import numpy as np
np.random.seed(99)
N, T, D = returns_scaled_rolled.shape
print('returns scaled rolled data shape: ', N, T, D)
ntrain = int(N*perc_of_train_used/100)
N_train = ntrain
xlist=list(range(N))
random.shuffle(xlist)
print (xlist[:5])

xtrain=returns_scaled_rolled[xlist[:ntrain],:]
xtest=returns_scaled_rolled[xlist[ntrain:],:]
print (xtrain.shape,xtest.shape)

scaled_train_data = xtrain
scaled_valid_data = xtest
# Out:
# returns scaled rolled data shape:  4082 24 9
# [2257, 1472, 3318, 1547, 455]
# (816, 24, 9) (3266, 24, 9)

# %%
# ----------------------------------------------------------------------------------
# instantiate the model     

latent_dim = 8

if vae_type == 'vae_dense': 
    vae = VAE_Dense( seq_len=T,  feat_dim = D, latent_dim = latent_dim, hidden_layer_sizes=[200,100], )
elif vae_type == 'vae_conv':
    vae = VAE_Conv( seq_len=T,  feat_dim = D, latent_dim = latent_dim, hidden_layer_sizes=[100, 200] )
elif vae_type == 'timeVAE':
    vae = TimeVAE( seq_len=T,  feat_dim = D, latent_dim = latent_dim, hidden_layer_sizes=[50, 100, 200],        #[80, 200, 250] 
            reconstruction_wt = 3.0,
            # ---------------------
            # disable following three arguments to use the model as TimeVAE_Base. Enabling will convert to Interpretable version.
            # Also set use_residual_conn= False if you want to only have interpretable components, and no residual (non-interpretable) component. 
            
            # trend_poly=2, 
            # custom_seas = [ (6,1), (7, 1), (8,1), (9,1)] ,     # list of tuples of (num_of_seasons, len_per_season)
            # use_scaler = True,
            
            #---------------------------
            use_residual_conn = True
        )   
else:  raise Exception('wut')


vae.compile(optimizer=Adam())
# vae.summary() ; sys.exit()

early_stop_loss = 'loss'
early_stop_callback = EarlyStopping(monitor=early_stop_loss, min_delta = 1e-1, patience=10) 
reduceLR = ReduceLROnPlateau(monitor='loss', factor=0.1, patience=5)

history = vae.fit(
    scaled_train_data, 
    batch_size = 32,
    epochs=100,
    shuffle = True,
    callbacks=[early_stop_callback, reduceLR],
    verbose = 1
)

# ----------------------------------------------------------------------------------    
# save model 
model_dir = './model/'
file_pref = f'vae_{vae_type}_{dataset}_perc_{perc_of_train_used}_iter_{0}_'
vae.save(model_dir, file_pref)

# ----------------------------------------------------------------------------------
# visually check reconstruction 
X = scaled_train_data

x_decoded = vae.predict(scaled_train_data)
print('x_decoded.shape', x_decoded.shape)

### compare original and posterior predictive (reconstructed) samples
utils.draw_orig_and_post_pred_sample(X, x_decoded, n=5)


# # Plot the prior generated samples over different areas of the latent space
if latent_dim == 2: utils.plot_latent_space_timeseries(vae, n=8, figsize = (20, 10))
    
# # ----------------------------------------------------------------------------------
# draw random prior samples
num_samples = N_train
# print("num_samples: ", num_samples)

samples = vae.get_prior_samples(num_samples=num_samples)

utils.plot_samples(samples, n=5)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 3s 112ms/step - loss: 25544.0972 - reconstruction_loss: 7787.5747 - kl_loss: 355.5885 - acf_loss: 3.7991 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 3s 108ms/step - loss: 24635.8846 - reconstruction_loss: 7417.6582 - kl_loss: 253.4905 - acf_loss: 5.9805 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 3s 105ms/step - loss: 23598.2469 - reconstruction_loss: 7369.6558 - kl_loss: 238.9168 - acf_loss: 3.1692 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 3s 112ms/step - loss: 25089.1529 - reconstruction_loss: 7305.4756 - kl_loss: 244.7251 - acf_loss: 2.7512 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 3s 107ms/step - loss: 21423.1598 - reconstruction_loss: 7193.3872 - kl_loss: 265.6608 - acf_loss: 3.8538 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 3s 111ms/step - loss: 20953.2243 - reconstruction_loss: 7119.5503 - kl_loss: 258.2078 - acf_loss: 3.6680 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 3s 108ms/step - loss: 23807.5532 - reconstruction_loss: 7123.1226 - kl_loss: 258.6376 - acf_loss: 3.8063 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 3s 110ms/step - loss: 21351.4498 - reconstruction_loss: 6993.5854 - kl_loss: 264.0953 - acf_loss: 3.2182 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - 3s 106ms/step - loss: 21623.9159 - reconstruction_loss: 6816.0630 - kl_loss: 320.6858 - acf_loss: 1.9332 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 3s 106ms/step - loss: 20737.7974 - reconstruction_loss: 6626.1431 - kl_loss: 351.2679 - acf_loss: 2.0408 - lr: 0.0010
# Epoch 11/100
# 26/26 [==============================] - 3s 106ms/step - loss: 19301.3359 - reconstruction_loss: 6394.5474 - kl_loss: 417.0854 - acf_loss: 1.7931 - lr: 0.0010
# Epoch 12/100
# 26/26 [==============================] - 3s 110ms/step - loss: 19573.5451 - reconstruction_loss: 6290.4731 - kl_loss: 407.6440 - acf_loss: 1.7443 - lr: 0.0010
# Epoch 13/100
# 26/26 [==============================] - 3s 111ms/step - loss: 19422.7948 - reconstruction_loss: 6094.8667 - kl_loss: 431.8356 - acf_loss: 1.5738 - lr: 0.0010
# Epoch 14/100
# 26/26 [==============================] - 3s 105ms/step - loss: 17246.2751 - reconstruction_loss: 5904.7979 - kl_loss: 423.7183 - acf_loss: 1.7822 - lr: 0.0010
# Epoch 15/100
# 26/26 [==============================] - 3s 107ms/step - loss: 16416.6339 - reconstruction_loss: 5730.7588 - kl_loss: 461.4658 - acf_loss: 1.5378 - lr: 0.0010
# Epoch 16/100
# 26/26 [==============================] - 3s 109ms/step - loss: 16457.3134 - reconstruction_loss: 5602.6567 - kl_loss: 455.8247 - acf_loss: 1.5013 - lr: 0.0010
# Epoch 17/100
# 26/26 [==============================] - 3s 106ms/step - loss: 18322.1573 - reconstruction_loss: 5569.1113 - kl_loss: 460.4268 - acf_loss: 1.5719 - lr: 0.0010
# Epoch 18/100
# 26/26 [==============================] - 3s 105ms/step - loss: 17004.0975 - reconstruction_loss: 5509.8311 - kl_loss: 486.3771 - acf_loss: 1.3132 - lr: 0.0010
# Epoch 19/100
# 26/26 [==============================] - 3s 108ms/step - loss: 16026.3970 - reconstruction_loss: 5276.5781 - kl_loss: 504.0158 - acf_loss: 1.6251 - lr: 0.0010
# Epoch 20/100
# 26/26 [==============================] - 3s 107ms/step - loss: 15330.1327 - reconstruction_loss: 5136.2290 - kl_loss: 511.0677 - acf_loss: 1.3757 - lr: 0.0010
# Epoch 21/100
# 26/26 [==============================] - 3s 108ms/step - loss: 15388.2816 - reconstruction_loss: 5131.2480 - kl_loss: 505.2169 - acf_loss: 1.2412 - lr: 0.0010
# Epoch 22/100
# 26/26 [==============================] - 3s 109ms/step - loss: 16227.0878 - reconstruction_loss: 5000.7378 - kl_loss: 516.4986 - acf_loss: 1.2426 - lr: 0.0010
# Epoch 23/100
# 26/26 [==============================] - 3s 106ms/step - loss: 14941.5167 - reconstruction_loss: 4791.0859 - kl_loss: 549.1636 - acf_loss: 1.2396 - lr: 0.0010
# Epoch 24/100
# 26/26 [==============================] - 3s 105ms/step - loss: 15416.1897 - reconstruction_loss: 4646.0371 - kl_loss: 551.1064 - acf_loss: 1.3568 - lr: 0.0010
# Epoch 25/100
# 26/26 [==============================] - 3s 109ms/step - loss: 13077.1296 - reconstruction_loss: 4484.2891 - kl_loss: 584.6799 - acf_loss: 1.0797 - lr: 0.0010
# Epoch 26/100
# 26/26 [==============================] - 3s 106ms/step - loss: 14180.9933 - reconstruction_loss: 4430.8623 - kl_loss: 574.8472 - acf_loss: 1.2006 - lr: 0.0010
# Epoch 76/100
# 26/26 [==============================] - 3s 106ms/step - loss: 7402.9132 - reconstruction_loss: 2236.0654 - kl_loss: 649.8460 - acf_loss: 0.3091 - lr: 0.0010
# Epoch 77/100
# 26/26 [==============================] - 4s 141ms/step - loss: 7562.1906 - reconstruction_loss: 2223.5986 - kl_loss: 654.5253 - acf_loss: 0.2952 - lr: 0.0010
# Epoch 78/100
# 26/26 [==============================] - 3s 104ms/step - loss: 7292.2824 - reconstruction_loss: 2210.7366 - kl_loss: 674.2750 - acf_loss: 0.2766 - lr: 0.0010
# Epoch 79/100
# 26/26 [==============================] - 3s 102ms/step - loss: 7440.7827 - reconstruction_loss: 2191.1213 - kl_loss: 663.5173 - acf_loss: 0.3037 - lr: 0.0010
# Epoch 80/100
# 26/26 [==============================] - 3s 104ms/step - loss: 7349.0660 - reconstruction_loss: 2214.3132 - kl_loss: 674.0180 - acf_loss: 0.3077 - lr: 0.0010
# Epoch 81/100
# 26/26 [==============================] - 3s 108ms/step - loss: 7304.7777 - reconstruction_loss: 2217.9041 - kl_loss: 650.4449 - acf_loss: 0.2712 - lr: 0.0010
# Epoch 82/100
# 26/26 [==============================] - 3s 134ms/step - loss: 7836.1987 - reconstruction_loss: 2249.2563 - kl_loss: 672.2809 - acf_loss: 0.4225 - lr: 0.0010
# Epoch 83/100
# 26/26 [==============================] - 3s 109ms/step - loss: 7208.1158 - reconstruction_loss: 2173.6802 - kl_loss: 658.8380 - acf_loss: 0.2971 - lr: 0.0010
# Epoch 84/100
# 26/26 [==============================] - 3s 99ms/step - loss: 7400.6992 - reconstruction_loss: 2181.7512 - kl_loss: 666.8135 - acf_loss: 0.2696 - lr: 0.0010
# Epoch 85/100
# 26/26 [==============================] - 3s 123ms/step - loss: 7073.7654 - reconstruction_loss: 2143.4780 - kl_loss: 675.0701 - acf_loss: 0.2746 - lr: 0.0010
# Epoch 86/100
# 26/26 [==============================] - 3s 123ms/step - loss: 6949.1641 - reconstruction_loss: 2102.4792 - kl_loss: 659.3546 - acf_loss: 0.2957 - lr: 0.0010
# Epoch 87/100
# 26/26 [==============================] - 3s 97ms/step - loss: 7104.9767 - reconstruction_loss: 2103.4722 - kl_loss: 664.5193 - acf_loss: 0.2791 - lr: 0.0010
# Epoch 88/100
# 26/26 [==============================] - 2s 91ms/step - loss: 7178.5006 - reconstruction_loss: 2089.9883 - kl_loss: 666.2917 - acf_loss: 0.2734 - lr: 0.0010
# Epoch 89/100
# 26/26 [==============================] - 2s 85ms/step - loss: 6952.5571 - reconstruction_loss: 2093.1179 - kl_loss: 666.5116 - acf_loss: 0.2729 - lr: 0.0010
# Epoch 90/100
# 26/26 [==============================] - 3s 96ms/step - loss: 7146.9155 - reconstruction_loss: 2151.7932 - kl_loss: 671.1349 - acf_loss: 0.3003 - lr: 0.0010
# Epoch 91/100
# 26/26 [==============================] - 3s 99ms/step - loss: 7052.9571 - reconstruction_loss: 2149.2808 - kl_loss: 650.4370 - acf_loss: 0.3102 - lr: 0.0010
# Epoch 92/100
# 26/26 [==============================] - 3s 97ms/step - loss: 6836.9962 - reconstruction_loss: 2075.3628 - kl_loss: 682.7083 - acf_loss: 0.3070 - lr: 0.0010
# Epoch 93/100
# 26/26 [==============================] - 3s 100ms/step - loss: 7082.6200 - reconstruction_loss: 2099.2000 - kl_loss: 677.6755 - acf_loss: 0.2827 - lr: 0.0010
# Epoch 94/100
# 26/26 [==============================] - 3s 98ms/step - loss: 7073.7638 - reconstruction_loss: 2097.1470 - kl_loss: 666.5060 - acf_loss: 0.2954 - lr: 0.0010
# Epoch 95/100
# 26/26 [==============================] - 2s 96ms/step - loss: 6805.3998 - reconstruction_loss: 2096.4331 - kl_loss: 675.2197 - acf_loss: 0.2791 - lr: 0.0010
# Epoch 96/100
# 26/26 [==============================] - 3s 98ms/step - loss: 7085.0931 - reconstruction_loss: 2069.8774 - kl_loss: 678.8770 - acf_loss: 0.2643 - lr: 0.0010
# Epoch 97/100
# 26/26 [==============================] - 2s 96ms/step - loss: 6922.0428 - reconstruction_loss: 2030.1444 - kl_loss: 668.7604 - acf_loss: 0.2542 - lr: 0.0010
# Epoch 98/100
# 26/26 [==============================] - 3s 97ms/step - loss: 6685.6806 - reconstruction_loss: 1978.5938 - kl_loss: 670.0258 - acf_loss: 0.2223 - lr: 0.0010
# Epoch 99/100
# 26/26 [==============================] - 3s 99ms/step - loss: 6768.5831 - reconstruction_loss: 1946.2292 - kl_loss: 688.6583 - acf_loss: 0.2292 - lr: 0.0010
# Epoch 100/100
# 26/26 [==============================] - 3s 97ms/step - loss: 6531.6203 - reconstruction_loss: 1918.0150 - kl_loss: 682.6580 - acf_loss: 0.2257 - lr: 0.0010
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 47
#      45 model_dir = './model/'
#      46 file_pref = f'vae_{vae_type}_{dataset}_perc_{perc_of_train_used}_iter_{0}_'
# ---> 47 vae.save(model_dir, file_pref)
#      49 # ----------------------------------------------------------------------------------
#      50 # visually check reconstruction
#      51 X = scaled_train_data
#
# File c:\Temp\python\Machine_learning_scenario_generation\GitHub\timeVAE\vae_conv_I_model_acf.py:293, in VariationalAutoencoderConvInterpretable.save(self, model_dir, file_pref)
#     291 def save(self, model_dir, file_pref):
# --> 293     super().save_weights(model_dir, file_pref)
#     294     dict_params = {
#     295         'seq_len': self.seq_len,
#     296         'feat_dim': self.feat_dim,
#    (...)
#     305         'use_residual_conn': self.use_residual_conn,
#     306     }
#     307     params_file = os.path.join(model_dir, f'{file_pref}parameters.pkl')
#
# File c:\Temp\python\Machine_learning_scenario_generation\GitHub\timeVAE\vae_base_acf.py:223, in BaseVariationalAutoencoder.save_weights(self, model_dir, file_pref)
#     221 encoder_wts = self.encoder.get_weights()
#     222 decoder_wts = self.decoder.get_weights()
# --> 223 joblib.dump(encoder_wts, os.path.join(model_dir, f'{file_pref}encoder_wts.h5'))
#     224 joblib.dump(decoder_wts, os.path.join(model_dir, f'{file_pref}decoder_wts.h5'))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './model/vae_timeVAE_yield-curve-rates-1990-2021_perc_20_iter_0_encoder_wts.h5'

# %%
loss_history = history.history["loss"]
numpy_loss_history = np.array(loss_history)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['reconstruction_loss'])
plt.plot(history.history['kl_loss'])
plt.plot(history.history['acf_loss'])
plt.legend(['Loss', 'Reconstruction loss', 'KL loss', 'ACF loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# inverse-transform scaling 
# samples = scaler.inverse_transform(samples)
samples = inverse_trans(samples, scaler)
print('shape of gen samples: ', samples.shape) 

# ----------------------------------------------------------------------------------
# save samples
output_dir = './outputs/'
sample_fname = f'{vae_type}_gen_samples_{dataset}_perc_{perc_of_train_used}.npz' 
samples_fpath = os.path.join(output_dir, sample_fname) 
np.savez_compressed(samples_fpath, data=samples)

# ----------------------------------------------------------------------------------

# later.... load model 
if vae_type == 'timeVAE':
    new_vae = TimeVAE.load(model_dir, file_pref)
elif vae_type == 'vae_conv':
    new_vae = VAE_Conv.load(model_dir, file_pref)
else:
    new_vae = VAE_Dense.load(model_dir, file_pref)

new_x_decoded = new_vae.predict(scaled_train_data)
# print('new_x_decoded.shape', new_x_decoded.shape)

print('Preds from orig and loaded models equal: ', np.allclose( x_decoded,  new_x_decoded, atol=1e-5))        

# ----------------------------------------------------------------------------------

end = time.time()
print(f"Total run time: {np.round((end - start)/60.0, 2)} minutes")
# Out:
# shape of gen samples:  (816, 24, 9)
# 26/26 [==============================] - 1s 20ms/step
# Preds from orig and loaded models equal:  True
# Total run time: 25.93 minutes

# %%
from lib.plot import *
plot_summary(x_fake=torch.from_numpy(new_x_decoded), x_real=torch.from_numpy(scaled_train_data), max_lag=10)

# %%
# import random
# import numpy
# from matplotlib import pyplot

# bins = numpy.linspace(-5, 5, 100)
# for i in range(D):

#     pyplot.hist(scaled_train_data[:,:,i], bins, alpha=0.5, label='Real')
#     pyplot.hist(new_x_decoded[:,:,i], bins, alpha=0.5, label='Synthetic')
#     pyplot.legend(loc='upper right')
#     pyplot.show()

# %%
sys.path.insert(0, '../metrics/')
# from discriminative_metrics3 import discriminative_score_metrics
from discriminative_metrics2 import discriminative_score_metrics
from predictive_metrics3 import predictive_score_metrics
from visualization_metrics import visualization

# %%
metric_iteration = 2

pred_epochs = 50
disc_epochs = 50 

print_period = 10

predictive_score, discriminative_score = [], []
for tt in range(metric_iteration):
    temp_pred = predictive_score_metrics(scaled_train_data, new_x_decoded, 
                                            predictor = 'conv', # conv, rnn, nbeats
                                            epochs = pred_epochs, print_epochs = print_period)
#         temp_pred = -1
    predictive_score.append(temp_pred)  
#         print(temp_pred); continue

    temp_disc = discriminative_score_metrics(scaled_train_data, new_x_decoded, print_epochs=print_period)
#         temp_disc = -1
    discriminative_score.append(temp_disc)   
    print(tt, temp_pred, temp_disc)
# Out:
# Pred Avg. train / val loss for epoch 10: 0.468 / 0.424
# Pred Avg. train / val loss for epoch 20: 0.462 / 0.42
# Pred Avg. train / val loss for epoch 30: 0.457 / 0.416
# Pred Avg. train / val loss for epoch 40: 0.454 / 0.414
# Pred Avg. train / val loss for epoch 50: 0.452 / 0.413
# Disc Avg. train / val loss for epoch 10: 0.692 / 0.71
# Disc Avg. train / val loss for epoch 20: 0.671 / 0.705
# Disc Avg. train / val loss for epoch 30: 0.553 / 0.62
# Disc Avg. train / val loss for epoch 40: 0.44 / 0.507
# Disc Avg. train / val loss for epoch 50: 0.354 / 0.39
# Disc Avg. train / val loss for epoch 60: 0.244 / 0.293
# Disc Avg. train / val loss for epoch 70: 0.2 / 0.261
# Disc Avg. train / val loss for epoch 80: 0.168 / 0.236
# Disc Avg. train / val loss for epoch 90: 0.15 / 0.22
# Disc Avg. train / val loss for epoch 100: 0.139 / 0.209
# Disc Avg. train / val loss for epoch 110: 0.132 / 0.203
# Disc Avg. train / val loss for epoch 120: 0.126 / 0.196
# Disc Avg. train / val loss for epoch 130: 0.121 / 0.191
# Disc Avg. train / val loss for epoch 140: 0.117 / 0.19
# Disc Avg. train / val loss for epoch 150: 0.113 / 0.189
# Disc Avg. train / val loss for epoch 160: 0.11 / 0.188
# Disc Avg. train / val loss for epoch 170: 0.107 / 0.185
# Disc Avg. train / val loss for epoch 180: 0.103 / 0.185
# Disc Avg. train / val loss for epoch 190: 0.101 / 0.185
# 11/11 [==============================] - 0s 29ms/step
# 0 0.7492691907303386 0.43272171253822633
# Pred Avg. train / val loss for epoch 10: 0.468 / 0.482
# Pred Avg. train / val loss for epoch 20: 0.462 / 0.478
# Pred Avg. train / val loss for epoch 30: 0.459 / 0.474
# Pred Avg. train / val loss for epoch 40: 0.457 / 0.472
# Pred Avg. train / val loss for epoch 50: 0.455 / 0.47
# Disc Avg. train / val loss for epoch 10: 0.701 / 0.699
# Disc Avg. train / val loss for epoch 20: 0.689 / 0.697
# Disc Avg. train / val loss for epoch 30: 0.681 / 0.698
# Disc Avg. train / val loss for epoch 40: 0.67 / 0.698
# Disc Avg. train / val loss for epoch 50: 0.642 / 0.686
# Disc Avg. train / val loss for epoch 60: 0.467 / 0.474
# Disc Avg. train / val loss for epoch 70: 0.334 / 0.334
# Disc Avg. train / val loss for epoch 80: 0.276 / 0.298
# Disc Avg. train / val loss for epoch 90: 0.238 / 0.278
# Disc Avg. train / val loss for epoch 100: 0.215 / 0.262
# Disc Avg. train / val loss for epoch 110: 0.195 / 0.253
# Disc Avg. train / val loss for epoch 120: 0.183 / 0.252
# Disc Avg. train / val loss for epoch 130: 0.173 / 0.251
# Disc Avg. train / val loss for epoch 140: 0.164 / 0.248
# Disc Avg. train / val loss for epoch 150: 0.157 / 0.242
# Disc Avg. train / val loss for epoch 160: 0.151 / 0.248
# Disc Avg. train / val loss for epoch 170: 0.144 / 0.237
# Disc Avg. train / val loss for epoch 180: 0.139 / 0.238
# Disc Avg. train / val loss for epoch 190: 0.133 / 0.235
# 11/11 [==============================] - 0s 28ms/step
# 1 0.7448773096177362 0.40825688073394495

# %%
print("-"*90); print('Visualizations:')
visualization(scaled_train_data[0:new_x_decoded.shape[0]], new_x_decoded, 'pca')
visualization(scaled_train_data[0:new_x_decoded.shape[0]], new_x_decoded, 'tsne')
# Out:
# ------------------------------------------------------------------------------------------
# Visualizations:
